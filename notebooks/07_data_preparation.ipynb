# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

print(PROJECT_ROOT)
# Out:
# c:\Users\HP\Desktop\RF Signal Processing\RF-Signal-Classification-using-ML

# %%
import pandas as pd

from src.features.data_preparation import scale_features

X_train = pd.read_csv(
    PROJECT_ROOT / "data/processed/X_train.csv"
)

X_test = pd.read_csv(
    PROJECT_ROOT / "data/processed/X_test.csv"
)

# %%
X_train_scaled, X_test_scaled, scaler = scale_features(
    X_train,
    X_test,
    PROJECT_ROOT / "data/processed"
)

# %%
print(X_train_scaled.shape)
print(X_test_scaled.shape)
# Out:
# (176000, 31)
# (44000, 31)
